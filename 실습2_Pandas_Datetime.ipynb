# %% [markdown]
# <a href="https://colab.research.google.com/github/JinGunseon/FinanceDataAnalysis/blob/main/%EC%8B%A4%EC%8A%B52_Pandas_Datetime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 시계열 관련 NumPy 및 Pandas 기능

# %% [markdown]
# ## python, numpy, pandas 날짜 타입 비교 및 정리
#
# |라이브러리|날짜, 시간 클래스| 타임델타 클래스|
# |-------|-------------|-------------|
# |datetime|datetime, date, time|timedelta|
# |numpy|datetime64|timedelta64|
# |panads|Timestamp|Timedelta|
#
# - datetime은 python 설치 시 기본적으로 내장된 라이브러리로, 날짜를 쓸 것인지, 시간을 쓸 것인지, 날짜와 시간을 합쳐쓸 것인지에 따라 클래스가 분화되어 있음.
# 예를들어 `2021-3-16` (날짜)을 표시하고 싶으면 `date` 클래스를 사용하고, `2021-3-16 12:34:2` (날짜+시간)를 표시하고 싶으면 `datetime` 클래스를 사용.
#
#
# - `datetime64`나 `Timestamp`는 각각 numpy, pandas 라이브러리에서 새로 정의한 날짜시간 클래스.
# 이 둘은 한 클래스로 날짜, 시간, 날짜+시간을 모두 정의할 수 있는 것이 특징.

# %% [markdown]
# ### 날짜 데이터 정의 - python

# %%
import datetime

datetime.date(2022, 5, 1)
# Out:
# datetime.date(2022, 5, 1)

# %%
datetime.datetime(2022, 5, 1, 15, 30, 25)
# Out:
# datetime.datetime(2022, 5, 1, 15, 30, 25)

# %%
datetime.time(15,30,25)
# Out:
# datetime.time(15, 30, 25)

# %% [markdown]
# ### 날짜 데이터 정의 - numpy

# %%
import numpy as np

np.datetime64("2022-05-01 15:30:14")
# Out:
# np.datetime64('2022-05-01T15:30:14')

# %% [markdown]
# ### 날짜 데이터 정의 - pandas
# - pd.Timestamp :  python datetime.datetime 의 Pandas version
# - pd.to_datetime :  Scalar, array-like, Series or DataFrame/dictionary 형태 data를 pandas DatetimeIndex로 날짜 변환.

# %%
import pandas as pd

pd.Timestamp(2022,5,1)
# Out:
# Timestamp('2022-05-01 00:00:00')

# %%
pd.Timestamp('2022-5-1')
# Out:
# Timestamp('2022-05-01 00:00:00')

# %%
pd.Timestamp('2022/5/1')
# Out:
# Timestamp('2022-05-01 00:00:00')

# %%
pd.to_datetime(['2022-5-1','2022-5-2'])
#type(pd.to_datetime(['2022-5-1','2022-5-2']))
# Out:
# DatetimeIndex(['2022-05-01', '2022-05-02'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ### Numpy 의 datetime64 format
#
# - NumPy 날짜 배열은 ns(나노초) 단위의 datetime64 객체입니다.
# - 내부 저장 단위는 문자열 형태에서 자동으로 선택되며 날짜 단위 또는 시간 단위가 될 수 있습니다.
# - 날짜 단위는 년('Y'), 월('M'), 주('W'), 일('D')이고 시간 단위는 시('h'), 분('m'), 초('s'), 밀리초('ms') 입니다.

# %%
order_date = pd.Series(['2022-08-01 12:01:01', '2022-08-02 12:01:02',
                        '2022-08-03 12:01:03', '2022-08-04 12:01:04'])
order_date
# Out:
# 0    2022-08-01 12:01:01
# 1    2022-08-02 12:01:02
# 2    2022-08-03 12:01:03
# 3    2022-08-04 12:01:04
# dtype: object

# %%
order_date = pd.to_datetime(order_date)

# %% [markdown]
# `datetime64[D]` - 날짜

# %%
order_daily = np.array(order_date, dtype='datetime64[D]')
order_daily
# Out:
# array(['2022-08-01', '2022-08-02', '2022-08-03', '2022-08-04'],
#       dtype='datetime64[D]')

# %% [markdown]
# `datetime64[M]` - 월

# %%
order_month = np.array(order_date, dtype='datetime64[M]')
order_month
# Out:
# array(['2022-08', '2022-08', '2022-08', '2022-08'], dtype='datetime64[M]')

# %% [markdown]
# order_date_monthly = np.array(order_date, dtype='datetime64[M]')
# order_date_monthly

# %% [markdown]
# `'datetime64[Y]` - 연

# %%
order_year = np.array(order_date, dtype='datetime64[Y]')
order_year
# Out:
# array(['2022', '2022', '2022', '2022'], dtype='datetime64[Y]')

# %% [markdown]
# ## DateTimeIndex 를 가진 Pandas 시계열 data 생성 및 처리
#
# - Timestamp을 index 로 하는 data 를 시계열데이터 (TimeSeries) 라고 부른다. 즉, index 가 DatetimeIndex 인 데이터이다.
#
# - 시계열관련 class 와 생성 방법
#
# | class         |           설명          |                               생성방법 |Pandas Class|
# |---------------|:-----------------------:|---------------------------------------:|------------:|
# | Timestamp     |     하나의 timestamp    |                 to_datetime, Timestamp |pandas.Timestamp|
# | DatetimeIndex | timestamp 타입의 인덱스 | to_datetime, date_range, DatetimeIndex |pandas.DatetimeIndex|
# | Period        |       time period       |                                 Period |pandas.Period|

# %% [markdown]
# ## to_datetime()
#
# - 날짜/시간을 나타내는 **여러 종류의 문자열**을 자동으로 datetime 자료형으로 바꾼 후 DatetimeIndex 자료형 인덱스를 생성

# %%
date_str = ['2010-01-01', '2015, 7, 1', 'May, 1 2016', '2010/01/01',
            'Dec, 25, 2019', 'DEC 1 2020', 'dec 20 2021', '2020 12 31', '20201231' ]
pd.to_datetime(date_str, format='mixed')
# 다양한 형식의 날짜 문자열이 들어있는 경우, '2015, 7, 1' 같은 문자열은 %y-%M-%d 형식에 부합하는지 판단하기 애매. foramt='mixed'를 추가하여 다양한 형식이 혼재됨을 명시할 것
# Out:
# DatetimeIndex(['2010-01-01', '2015-07-01', '2016-05-01', '2010-01-01',
#                '2019-12-25', '2020-12-01', '2021-12-20', '2020-12-31',
#                '2020-12-31'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## date_range
# ```python
# pd.date_range(start, end, periods, freq)
# ```
#
# - 모든 날짜/시간을 일일히 입력할 필요없이 **시작일과 종료일** 또는 **시작일과 기간**을 입력하면 범위 내의 인덱스를 생성
#
# - freq
#     - S: 초
#     - T: 분
#     - H: 시간
#     - D: 일(day)
#     - B: 주말이 아닌 평일 (Business Day)
#     - W: 주(일요일)
#     - ME: 각 달(month)의 마지막 날
#     - MS: 각 달의 첫날
#
# [frequency alias](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#offset-aliases) 참조

# %% [markdown]
# start ~ 10일

# %%
pd.date_range('2022-05-01', '2022-05-10')
# Out:
# DatetimeIndex(['2022-05-01', '2022-05-02', '2022-05-03', '2022-05-04',
#                '2022-05-05', '2022-05-06', '2022-05-07', '2022-05-08',
#                '2022-05-09', '2022-05-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2022-05-01', periods=10)
# Out:
# DatetimeIndex(['2022-05-01', '2022-05-02', '2022-05-03', '2022-05-04',
#                '2022-05-05', '2022-05-06', '2022-05-07', '2022-05-08',
#                '2022-05-09', '2022-05-10'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# start~end 사이 평일

# %%
pd.date_range('2022-05-01', '2022-05-15', freq='B')
# Out:
# DatetimeIndex(['2022-05-02', '2022-05-03', '2022-05-04', '2022-05-05',
#                '2022-05-06', '2022-05-09', '2022-05-10', '2022-05-11',
#                '2022-05-12', '2022-05-13'],
#               dtype='datetime64[ns]', freq='B')

# %%
pd.date_range('2022-05-01', '2022-05-15', freq='W')
# Out:
# DatetimeIndex(['2022-05-01', '2022-05-08', '2022-05-15'], dtype='datetime64[ns]', freq='W-SUN')

# %% [markdown]
# start ~ 12 개월

# %%
pd.date_range('2022-05-01', '2022-12-31', freq='ME') #월말
# Out:
# DatetimeIndex(['2022-05-31', '2022-06-30', '2022-07-31', '2022-08-31',
#                '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-31'],
#               dtype='datetime64[ns]', freq='ME')

# %%
dates = pd.date_range('2022-01-01', '2022-12-31', freq='MS') #월초

# %% [markdown]
# DataFrame의 index를 datetime으로 변경

# %%
a = np.random.standard_normal((12, 4))
df = pd.DataFrame(a, columns=['n1', 'n2', 'n3', 'n4'])
df.index = dates
df
# Out:
#                   n1        n2        n3        n4
# 2022-01-01 -0.832754  1.283722 -0.526046  0.817218
# 2022-02-01 -0.816735  0.159862 -1.084651  0.293124
# 2022-03-01  1.114818 -1.502485 -0.644098 -0.059499
# 2022-04-01 -0.093053 -2.734348  2.379661 -0.372802
# 2022-05-01  0.744292  1.014973 -1.314393  0.183704
# 2022-06-01 -0.373118  0.388359  0.428362 -0.822305
# 2022-07-01 -0.270119 -0.074340  0.821141  0.114468
# 2022-08-01  0.089200  0.119401 -0.062880  0.440239
# 2022-09-01 -0.939825 -1.395837  0.408503  0.817956
# 2022-10-01 -0.699054  0.559419 -0.925632 -0.789387
# 2022-11-01  1.136451 -0.225514  0.379025 -2.515259
# 2022-12-01 -0.902765  1.670133 -0.308375 -0.886245

# %%
df.index
# Out:
# DatetimeIndex(['2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 2022-01-01 to 2022-12-01
# Freq: MS
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   n1      12 non-null     float64
#  1   n2      12 non-null     float64
#  2   n3      12 non-null     float64
#  3   n4      12 non-null     float64
# dtypes: float64(4)
# memory usage: 480.0 bytes

# %% [markdown]
# ## Pandas DatetimeIndex를 이용한 작업

# %%
dates = pd.date_range('2020-08-01', '2021-08-01', freq='ME')
a = np.random.randn(12)
df = pd.DataFrame({'date': dates, 'a': a})
df
# Out:
#          date         a
# 0  2020-08-31 -0.324597
# 1  2020-09-30  0.179407
# 2  2020-10-31  0.574972
# 3  2020-11-30  0.870488
# 4  2020-12-31  0.723278
# 5  2021-01-31 -0.104289
# 6  2021-02-28 -1.821703
# 7  2021-03-31  0.859364
# 8  2021-04-30 -0.196407
# 9  2021-05-31  1.541273
# 10 2021-06-30  0.271186
# 11 2021-07-31  2.380336

# %% [markdown]
# 기존의  numpy datetime64 format 변수를 사용하여 인덱스 설정

# %%
df.set_index('date',inplace=True)
df
# Out:
#                    a
# date
# 2020-08-31 -0.324597
# 2020-09-30  0.179407
# 2020-10-31  0.574972
# 2020-11-30  0.870488
# 2020-12-31  0.723278
# 2021-01-31 -0.104289
# 2021-02-28 -1.821703
# 2021-03-31  0.859364
# 2021-04-30 -0.196407
# 2021-05-31  1.541273
# 2021-06-30  0.271186
# 2021-07-31  2.380336

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 2020-08-31 to 2021-07-31
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       12 non-null     float64
# dtypes: float64(1)
# memory usage: 192.0 bytes

# %%
df.index
# Out:
# DatetimeIndex(['2020-08-31', '2020-09-30', '2020-10-31', '2020-11-30',
#                '2020-12-31', '2021-01-31', '2021-02-28', '2021-03-31',
#                '2021-04-30', '2021-05-31', '2021-06-30', '2021-07-31'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %% [markdown]
# ### Subsetting data
#
# 이제 DatetimeIndex를 사용하여 데이터 하위 집합을 선택할 수 있습니다.

# %%
df.loc['2020'] #loc: index의 value를 기준으로 행 추출
# Out:
#                    a
# date
# 2020-08-31 -0.324597
# 2020-09-30  0.179407
# 2020-10-31  0.574972
# 2020-11-30  0.870488
# 2020-12-31  0.723278

# %%
df.loc['2020-08':'2021-05']
# Out:
#                    a
# date
# 2020-08-31 -0.324597
# 2020-09-30  0.179407
# 2020-10-31  0.574972
# 2020-11-30  0.870488
# 2020-12-31  0.723278
# 2021-01-31 -0.104289
# 2021-02-28 -1.821703
# 2021-03-31  0.859364
# 2021-04-30 -0.196407
# 2021-05-31  1.541273

# %%
df.iloc[:5] #iloc: index의 인덱스 번호를 기준으로 행 추출
# Out:
#                    a
# date
# 2020-08-31 -0.324597
# 2020-09-30  0.179407
# 2020-10-31  0.574972
# 2020-11-30  0.870488
# 2020-12-31  0.723278

# %% [markdown]
# ### Datetime Components
#
# Pandas Datetime 변수에는 여러 가지 유용한 구성 요소가 있습니다. DatetimeIndex를 사용하여 월, 연도, 요일, 분기 등과 같은 항목을 추출할 수 있습니다.

# %% [markdown]
# DatetimeIndex에서 date 추출

# %%
df.index.day
# Out:
# Index([31, 30, 31, 30, 31, 31, 28, 31, 30, 31, 30, 31], dtype='int32', name='date')

# %% [markdown]
# - DatetimeIndex에서 day of week 추출 (Day of Week: Monday=0, Sunday=6)

# %%
df.index.dayofweek
# Out:
# Index([0, 2, 5, 0, 3, 6, 6, 2, 4, 0, 2, 5], dtype='int32', name='date')

# %%
df['DayofWeek'] = df.index.dayofweek
df
# Out:
#                    a  DayofWeek
# date
# 2020-08-31 -0.324597          0
# 2020-09-30  0.179407          2
# 2020-10-31  0.574972          5
# 2020-11-30  0.870488          0
# 2020-12-31  0.723278          3
# 2021-01-31 -0.104289          6
# 2021-02-28 -1.821703          6
# 2021-03-31  0.859364          2
# 2021-04-30 -0.196407          4
# 2021-05-31  1.541273          0
# 2021-06-30  0.271186          2
# 2021-07-31  2.380336          5

# %% [markdown]
# ## resample
#
# - 시간 간격을 재조정
# - 원래의 데이터가 그룹으로 묶이기 때문에 그룹 연산을 해서 대표값을 구해야 한다.

# %%
ts = pd.Series(np.random.randn(500), index=pd.date_range("2022-01-01", periods=500, freq="D"))
ts
# Out:
# 2022-01-01    1.066716
# 2022-01-02    0.479566
# 2022-01-03   -0.257338
# 2022-01-04    0.453381
# 2022-01-05   -1.149934
#                 ...
# 2023-05-11    0.149405
# 2023-05-12   -0.926733
# 2023-05-13    0.873565
# 2023-05-14   -0.442357
# 2023-05-15    1.284167
# Freq: D, Length: 500, dtype: float64

# %% [markdown]
# 월 단위 평균

# %%
ts.resample("ME").sum()
# Out:
# 2022-01-31     0.699841
# 2022-02-28    -0.557439
# 2022-03-31    -2.763971
# 2022-04-30    -5.270989
# 2022-05-31    -4.621640
# 2022-06-30     5.690424
# 2022-07-31    -9.013797
# 2022-08-31     0.286161
# 2022-09-30     8.353640
# 2022-10-31     4.102403
# 2022-11-30     1.842140
# 2022-12-31     0.629664
# 2023-01-31    11.405818
# 2023-02-28     4.515168
# 2023-03-31    -0.749237
# 2023-04-30     6.573821
# 2023-05-31     2.493602
# Freq: ME, dtype: float64

# %%
ts.resample("ME").mean()
# Out:
# 2022-01-31    0.022576
# 2022-02-28   -0.019909
# 2022-03-31   -0.089160
# 2022-04-30   -0.175700
# 2022-05-31   -0.149085
# 2022-06-30    0.189681
# 2022-07-31   -0.290768
# 2022-08-31    0.009231
# 2022-09-30    0.278455
# 2022-10-31    0.132336
# 2022-11-30    0.061405
# 2022-12-31    0.020312
# 2023-01-31    0.367930
# 2023-02-28    0.161256
# 2023-03-31   -0.024169
# 2023-04-30    0.219127
# 2023-05-31    0.166240
# Freq: ME, dtype: float64

# %%
ts.resample("ME").max()
# Out:
# 2022-01-31    1.313875
# 2022-02-28    1.406130
# 2022-03-31    2.529088
# 2022-04-30    2.376817
# 2022-05-31    2.139265
# 2022-06-30    1.640662
# 2022-07-31    2.620558
# 2022-08-31    1.375634
# 2022-09-30    1.834100
# 2022-10-31    1.900968
# 2022-11-30    1.884517
# 2022-12-31    2.030364
# 2023-01-31    2.806543
# 2023-02-28    1.963531
# 2023-03-31    1.980072
# 2023-04-30    1.552068
# 2023-05-31    1.402043
# Freq: ME, dtype: float64

# %% [markdown]
# 주 단위로 down-sampling

# %% [markdown]
# 주 단위 평균

# %%
ts.resample("W").sum()
# Out:
# 2022-01-02    1.546282
# 2022-01-09    1.976728
# 2022-01-16    2.495243
# 2022-01-23   -0.910531
# 2022-01-30   -4.512354
#                 ...
# 2023-04-23    0.558504
# 2023-04-30    1.925927
# 2023-05-07   -1.445847
# 2023-05-14    2.655282
# 2023-05-21    1.284167
# Freq: W-SUN, Length: 73, dtype: float64
